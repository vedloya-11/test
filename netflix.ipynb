# %%
import pandas as pd
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('netflix_titles.csv')
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
df.shape
# Out:
# (8807, 12)

# %%
df.isnull().agg('sum').sort_values(ascending=False)
# Out:
# director        2634
# country          831
# cast             825
# date_added        10
# rating             4
# duration           3
# show_id            0
# type               0
# title              0
# release_year       0
# listed_in          0
# description        0
# dtype: int64

# %%
round(df['director'].isnull().mean()*100, 2)
# Out:
# np.float64(29.91)

# %%
for column in df.columns:
    print(f'{column}: {round(df[column].isnull().mean()*100, 2)}')
# Out:
# show_id: 0.0
# type: 0.0
# title: 0.0
# director: 29.91
# cast: 9.37
# country: 9.44
# date_added: 0.11
# release_year: 0.0
# rating: 0.05
# duration: 0.03
# listed_in: 0.0
# description: 0.0

# %%
no_directors = df[df['director'].isnull()].index
df.drop(no_directors, axis=0)
# Out:
#      show_id     type                             title  \
# 0         s1    Movie              Dick Johnson Is Dead
# 2         s3  TV Show                         Ganglands
# 5         s6  TV Show                     Midnight Mass
# 6         s7    Movie  My Little Pony: A New Generation
# 7         s8    Movie                           Sankofa
# ...      ...      ...                               ...
# 8801   s8802    Movie                           Zinzana
# 8802   s8803    Movie                            Zodiac
# 8804   s8805    Movie                        Zombieland
# 8805   s8806    Movie                              Zoom
# 8806   s8807    Movie                            Zubaan
#
#                            director  \
# 0                   Kirsten Johnson
# 2                   Julien Leclercq
# 5                     Mike Flanagan
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# ...                             ...
# ...

# %%
df.drop(no_directors, axis=0, inplace=True)

# %%
df['rating'].mode()
# Out:
# 0    TV-MA
# Name: rating, dtype: object

# %%
ratings_mode = ''.join(df['rating'].mode())

# %%
df[df['rating'].isnull()]
# Out:
#      show_id   type                 title         director  \
# 7537   s7538  Movie  My Honor Was Loyalty  Alessandro Pepe
#
#                                                    cast country  \
# 7537  Leone Frisa, Paolo Vaccarino, Francesco Miglio...   Italy
#
#          date_added  release_year rating duration listed_in  \
# 7537  March 1, 2017          2015    NaN  115 min    Dramas
#
#                                             description
# 7537  Amid the chaos and horror of World War II, a c...

# %%
df['rating'].fillna(ratings_mode,inplace=True)

# %%
df['country'].fillna('Data Unavailable')
# Out:
# 0                                           United States
# 2                                        Data Unavailable
# 5                                        Data Unavailable
# 6                                        Data Unavailable
# 7       United States, Ghana, Burkina Faso, United Kin...
#                               ...
# 8801                         United Arab Emirates, Jordan
# 8802                                        United States
# 8804                                        United States
# 8805                                        United States
# 8806                                                India
# Name: country, Length: 6173, dtype: object

# %%
df['duration'].fillna('0 min', inplace=True)

# %%
df_movies = df[df['type'] == 'Movie'].copy()

# %%
df_movies['minutes'] = df_movies['duration'].str.split(expand=True)[0].astype(int)

# %%
(df_movies['date_added'].str.split(',', expand=True)[0])
# Out:
# 0       September 25
# 6       September 24
# 7       September 24
# 9       September 24
# 12      September 23
#             ...
# 8801         March 9
# 8802     November 20
# 8804      November 1
# 8805      January 11
# 8806         March 2
# Name: 0, Length: 5943, dtype: object

# %%
df_movies['date_added'].str.extract('(\d{1,2})')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# /tmp/ipython-input-2543568680.py:1: SyntaxWarning: invalid escape sequence '\d'
#   df_movies['date_added'].str.extract('(\d{1,2})')
#        0
# 0     25
# 6     24
# 7     24
# 9     24
# 12    23
# ...   ..
# 8801   9
# 8802  20
# 8804   1
# 8805  11
# 8806   2
#
# [5943 rows x 1 columns]

# %%
df_movies['minutes'].plot(kind='hist', bins=10)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df_movies['minutes'].value_counts(bins=10).sort_index()
# Out:
# (-0.254, 25.3]      72
# (25.3, 50.6]       157
# (50.6, 75.9]       567
# (75.9, 101.2]     2475
# (101.2, 126.5]    1813
# (126.5, 151.8]     631
# (151.8, 177.1]     178
# (177.1, 202.4]      34
# (202.4, 227.7]      10
# (227.7, 253.0]       6
# Name: count, dtype: int64

# %%
df_movies['minutes'].plot(kind='box', vert=False, figsize=(20,5))
# Out:
# <Axes: >

# %%
df_movies['minutes'].describe()
# Out:
# count    5943.000000
# mean      100.533064
# std        27.399894
# min         0.000000
# 25%        88.000000
# 50%        99.000000
# 75%       115.000000
# max       253.000000
# Name: minutes, dtype: float64

# %%
df_movies[(df_movies['minutes']>46)&(df_movies['minutes']<156)]
# Out:
#      show_id   type                             title  \
# 0         s1  Movie              Dick Johnson Is Dead
# 6         s7  Movie  My Little Pony: A New Generation
# 7         s8  Movie                           Sankofa
# 9        s10  Movie                      The Starling
# 12       s13  Movie                      Je Suis Karl
# ...      ...    ...                               ...
# 8799   s8800  Movie                             Zenda
# 8801   s8802  Movie                           Zinzana
# 8804   s8805  Movie                        Zombieland
# 8805   s8806  Movie                              Zoom
# 8806   s8807  Movie                            Zubaan
#
#                            director  \
# 0                   Kirsten Johnson
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# 9                    Theodore Melfi
# 12              Christian Schwochow
# ...                             ...
# 8799                 Avadhoot Gupte
# ...

# %%
df_movies['rating'].value_counts().plot(kind='bar', figsize=(10,5), grid=True)
# Out:
# <Axes: xlabel='rating'>
